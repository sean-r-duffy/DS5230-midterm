# %% [markdown]
# # Zillow Observed Rent Index (ZORI)
# https://www.zillow.com/research/data/

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## ZORI explained: https://www.zillow.com/research/methodology-zori-repeat-rent-27092/

# %%
city_df = pd.read_csv('City_zori_uc_sfrcondomfr_sm_month.csv')
city_df.head()
# Out:
#    RegionID  SizeRank   RegionName RegionType StateName State  \
# 0      6181         0     New York       city        NY    NY
# 1     12447         1  Los Angeles       city        CA    CA
# 2     39051         2      Houston       city        TX    TX
# 3     17426         3      Chicago       city        IL    IL
# 4      6915         4  San Antonio       city        TX    TX
#
#                                    Metro          CountyName   2015-01-31  \
# 0  New York-Newark-Jersey City, NY-NJ-PA       Queens County  2529.406862
# 1     Los Angeles-Long Beach-Anaheim, CA  Los Angeles County  1853.062009
# 2   Houston-The Woodlands-Sugar Land, TX       Harris County  1216.258914
# 3     Chicago-Naperville-Elgin, IL-IN-WI         Cook County  1482.794295
# 4          San Antonio-New Braunfels, TX        Bexar County   965.416689
#
#     2015-02-28  ...   2023-03-31   2023-04-30   2023-05-31   2023-06-30  \
# ...

# %%
metro_df = pd.read_csv('Metro_zori_uc_sfrcondomfr_sm_month.csv')
metro_df.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName   2015-01-31  \
# 0    102001         0    United States    country       NaN  1228.784000
# 1    394913         1     New York, NY        msa        NY  2286.942293
# 2    753899         2  Los Angeles, CA        msa        CA  1822.376921
# 3    394463         3      Chicago, IL        msa        IL  1385.601820
# 4    394514         4       Dallas, TX        msa        TX  1114.978459
#
#     2015-02-28   2015-03-31   2015-04-30   2015-05-31  ...   2023-03-31  \
# 0  1235.398148  1244.250266  1254.031553  1263.701003  ...  1913.956669
# 1  2302.441587  2319.715402  2341.394932  2356.920054  ...  3048.279317
# 2  1834.225694  1849.513160  1863.634189  1877.945479  ...  2822.067602
# 3  1392.861993  1403.350024  1412.784123  1423.690042  ...  1853.085095
# 4  1119.825663  1127.669715  1138.626074  1148.650766  ...  1764.604262
#
#     2023-04-30   2023-05-31   2023-06-30   2023-07-31   2023-08-31  \
# ...

# %%
zip_df = pd.read_csv('Zip_zori_uc_sfrcondomfr_sm_month.csv')
zip_df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 0     91982         1       77494        zip        TX    TX      Katy
# 1     91940         3       77449        zip        TX    TX      Katy
# 2     91733         5       77084        zip        TX    TX   Houston
# 3     93144         6       79936        zip        TX    TX   El Paso
# 4     62093         7       11385        zip        NY    NY  New York
#
#                                    Metro        CountyName   2015-01-31  ...  \
# 0   Houston-The Woodlands-Sugar Land, TX  Fort Bend County  1498.067627  ...
# 1   Houston-The Woodlands-Sugar Land, TX     Harris County  1290.517270  ...
# 2   Houston-The Woodlands-Sugar Land, TX     Harris County          NaN  ...
# 3                            El Paso, TX    El Paso County          NaN  ...
# 4  New York-Newark-Jersey City, NY-NJ-PA     Queens County          NaN  ...
#
#     2023-03-31   2023-04-30   2023-05-31   2023-06-30   2023-07-31  \
# ...

# %%
zip_df[zip_df['City']=='New York']
# Out:
#       RegionID  SizeRank  RegionName RegionType StateName State      City  \
# 4        62093         7       11385        zip        NY    NY  New York
# 6        62019         9       11208        zip        NY    NY  New York
# 13       62046        16       11236        zip        NY    NY  New York
# 14       61807        17       10467        zip        NY    NY  New York
# 15       62085        18       11373        zip        NY    NY  New York
# ...        ...       ...         ...        ...       ...   ...       ...
# 6023     61771     10844       10280        zip        NY    NY  New York
# 6108     61773     12178       10282        zip        NY    NY  New York
# 6116     62010     12258       11109        zip        NY    NY  New York
# 6179     61620     14713       10006        zip        NY    NY  New York
# 6240     61618     30490       10004        zip        NY    NY  New York
#
#                                       Metro       CountyName  2015-01-31  ...  \
# ...

# %%
zip_df.sort_values('SizeRank', ascending=True)
# Out:
#       RegionID  SizeRank  RegionName RegionType StateName State  \
# 0        91982         1       77494        zip        TX    TX
# 1        91940         3       77449        zip        TX    TX
# 2        91733         5       77084        zip        TX    TX
# 3        93144         6       79936        zip        TX    TX
# 4        62093         7       11385        zip        NY    NY
# ...        ...       ...         ...        ...       ...   ...
# 6237     72017     30490       32461        zip        FL    FL
# 6238     58956     30490        2876        zip        RI    RI
# 6239     91179     30490       76005        zip        TX    TX
# 6240     61618     30490       10004        zip        NY    NY
# 6241     97071     30490       92878        zip        CA    CA
#
#                    City                                   Metro  \
# 0                  Katy    Houston-The Woodlands-Sugar Land, TX
# 1                  Katy    Houston-The Woodlands-Sugar Land, TX
# ...

# %%
zip_df[zip_df['State']=='MA']
# Out:
#       RegionID  SizeRank  RegionName RegionType StateName State     City  \
# 290      58660       314        2148        zip        MA    MA   Malden
# 395      58666       429        2155        zip        MA    MA  Medford
# 431      58663       467        2151        zip        MA    MA   Revere
# 509      58669       547        2169        zip        MA    MA   Quincy
# 542      58638       581        2124        zip        MA    MA   Boston
# ...        ...       ...         ...        ...       ...   ...      ...
# 6162     58623     14047        2109        zip        MA    MA   Boston
# 6168     58622     14268        2108        zip        MA    MA   Boston
# 6171     58592     14487        2045        zip        MA    MA     Hull
# 6177     58538     14673        1901        zip        MA    MA     Lynn
# 6191     58387     15643        1503        zip        MA    MA   Berlin
#
#                                Metro        CountyName   2015-01-31  ...  \
# ...

# %%
zip_df[zip_df['RegionName']==2445]
# Out:
#       RegionID  SizeRank  RegionName RegionType StateName State       City  \
# 4497     58757      5612        2445        zip        MA    MA  Brookline
#
#                                Metro      CountyName   2015-01-31  ...  \
# 4497  Boston-Cambridge-Newton, MA-NH  Norfolk County  2939.081818  ...
#
#        2023-03-31   2023-04-30   2023-05-31   2023-06-30   2023-07-31  \
# 4497  4164.066332  4194.371891  4195.881994  4213.708814  4225.876049
#
#        2023-08-31   2023-09-30   2023-10-31   2023-11-30   2023-12-31
# 4497  4195.620908  4136.271284  4192.977152  4213.471323  4291.222222
#
# [1 rows x 117 columns]
